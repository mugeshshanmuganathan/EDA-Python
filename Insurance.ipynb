# %%
import pandas as pa
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pa.read_csv('insurance.csv')

# %%
df
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
# ...

# %%
print(df. to_string)
# Out:
# <bound method DataFrame.to_string of        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
# ...

# %%
df.head(50)
# Out:
#      age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0   18.0    male  23.210       0.0     no  29087.543130                17.0
# 1   18.0    male  30.140       0.0     no  39053.674370                 7.0
# 2   18.0    male  33.330       0.0     no  39023.627590                19.0
# 3   18.0    male  33.660       0.0     no  28185.393320                11.0
# 4   18.0    male  34.100       0.0     no  14697.859410                16.0
# 5   18.0    male  34.430       0.0     no  26488.339120                20.0
# 6   18.0    male  37.290       0.0     no  33217.365480                13.0
# 7   18.0    male  41.140       0.0     no  46770.585330                12.0
# 8   18.0    male  43.010       0.0     no   9715.650411                17.0
# 9   18.0    male  53.130       0.0     no  17046.585150                19.0
# 10  19.0    male  19.800       0.0     no  16980.214030                 2.0
# ...

# %%
df.tail(10)
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 1328  44.0  female  38.060       0.0    yes   76028.85348                25.0
# 1329  59.0    male  41.140       1.0    yes   53104.92621                38.0
# 1330  64.0    male  36.960       2.0    yes   65641.24823                28.0
# 1331  28.0    male  36.400       1.0    yes   55590.75527                26.0
# 1332  60.0    male  32.800       0.0    yes   77277.98848                40.0
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
#       num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# ...

# %%
df.shape
# Out:
# (1338, 13)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
# ...

# %%
df.describe()
# Out:
#                age          bmi     children  Claim_Amount  \
# count  1329.000000  1335.000000  1333.000000   1324.000000
# mean     39.310008    30.665112     1.090773  33361.327180
# std      14.034818     6.101690     1.201856  15617.288337
# min      18.000000    15.960000     0.000000   1920.136268
# 25%      27.000000    26.302500     0.000000  20768.860390
# 50%      39.000000    30.400000     1.000000  33700.310675
# 75%      51.000000    34.687500     2.000000  45052.331957
# max      64.000000    53.130000     5.000000  77277.988480
#
#        past_consultations  num_of_steps  Hospital_expenditure  \
# count         1332.000000  1.335000e+03          1.334000e+03
# mean            15.216216  9.100047e+05          1.584179e+07
# std              7.467723  9.188612e+04          2.669305e+07
# min              1.000000  6.954300e+05          2.945253e+04
# 25%              9.000000  8.471995e+05          4.077633e+06
# ...

# %%
#Data cleaning

'''
1) check for null/missing values
2) Check duplicaate records
3) check Outliers
'''
# Out:
# '\n1) check for null/missing values\n2) Check duplicaate records\n3) check Outliers\n'

# %%
df.isnull().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# age                                0
# sex                                0
# bmi                                0
# children                           0
# smoker                             0
# Claim_Amount                       0
# past_consultations                 0
# num_of_steps                       0
# Hospital_expenditure               0
# NUmber_of_past_hospitalizations    0
# Anual_Salary                       0
# region                             0
# charges                            0
# dtype: int64

# %%
df.shape
# Out:
# (1287, 13)

# %%
## if the Null values are lesser than 30% of total values, drop it if not fill it with mean or median

# %%
#Duplicate values

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
sns.boxplot(y=df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
for i in df.columns:
    if df[i].dtypes =='int64' or  df[i].dtypes =='float64':
        plt.boxplot(df[i])
        plt.xlabel(i)
        plt.show()

# %%
for i in df.columns:
    if df[i].dtypes =='int64' or  df[i].dtypes =='float64':
        Q1=df[i].quantile(0.25)
        Q3=df[i].quantile(0.75)
        IQR= Q3-Q1
        Upper_fen= Q3+1.5*IQR
        lower_fen= Q1-1.5*IQR
        df = df[ (df[i] >= lower_fen) & (df[i] <= Upper_fen)]

# %%
for i in df.columns:
    if df[i].dtypes =='int64' or  df[i].dtypes =='float64':
        plt.boxplot(df[i])
        plt.xlabel(i)
        plt.show()

# %%
count = df['sex'].value_counts()
print(count)
# Out:
# sex
# female    447
# male      374
# Name: count, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# female    447
# male      374
# Name: count, dtype: int64

# %%
df = pa.DataFrame(df)

counts = df['sex'].value_counts()

plt.figure(figsize=(4,4))
counts.plot.pie(autopct='%1.1f%%', startangle=90, shadow=True)

plt.title('Gender')
plt.show()

# %%
avg_salary = df.groupby('region')['Anual_Salary'].mean()  
print(avg_salary)
# Out:
# region
# northeast    1.398241e+08
# northwest    1.321392e+08
# southeast    1.286773e+08
# southwest    1.329613e+08
# Name: Anual_Salary, dtype: float64

# %%
count = df[(df['sex'] == 'male') & (df['bmi'] > 40)].shape[0]
print("Number of males with BMI lesser than 40:", count,"males")
# Out:
# Number of males with BMI lesser than 40: 23 males
